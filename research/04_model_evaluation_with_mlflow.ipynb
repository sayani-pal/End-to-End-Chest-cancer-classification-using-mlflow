# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\palsa\\OneDrive\\Desktop\\End-to-End-Chest-cancer-classification-using-mlflow\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\palsa\\OneDrive\\Desktop\\End-to-End-Chest-cancer-classification-using-mlflow'

# %%
os.environ["MLFLOW_TRACKING_URI"]="https://dagshub.com/pal.sayani.2005/End-to-End-Chest-cancer-classification-using-mlflow.mlflow"
os.environ["MLFLOW_TRACKING_USERNAME"]="pal.sayani.2005"
os.environ["MLFLOW_TRACKING_PASSWORD"]="bb1587625ce9b36af90750b6b4577719041775d6"
